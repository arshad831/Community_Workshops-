# %% [markdown]
# <a href="https://colab.research.google.com/github/arshad831/Community_Workshops-/blob/main/Unicorn_companies_analysisworkshop-2ndAugust.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('Unicorn_Companies.csv')

# Display the first few rows of the dataframe
df.head(50)
# Out:
#                    Company Valuation ($B) Date Joined         Country  \
# 0                Bytedance          $140     4/7/2017           China
# 1                   SpaceX       $100.30    12/1/2012   United States
# 2                   Stripe           $95    1/23/2014   United States
# 3                   Klarna        $45.60   12/12/2011          Sweden
# 4               Epic Games           $42   10/26/2018   United States
# 5                    Canva           $40     1/8/2018       Australia
# 6             Checkout.com           $40     5/2/2019  United Kingdom
# 7                Instacart           $39   12/30/2014   United States
# 8               Databricks           $38     2/5/2019   United States
# 9                  Revolut           $33    4/26/2018  United Kingdom
# 10                     FTX           $32    7/20/2021         Bahamas
# 11                Fanatics           $27     6/6/2012   United States
# 12                   Chime           $25     3/5/2019   United States
# 13                  BYJU's           $21    7/25/2017           India
# 14             Xiaohongshu           $20    3/31/2016           China
# 15             J&T Express           $20     4/7/2021       Indonesia
# 16                    Miro        $17.50     1/5/2022   United States
# 17               Yuanfudao        $15.50    5/31/2017           China
# 18         DJI Innovations           $15    1/23/2015           China
# 19                   SHEIN           $15     7/3/2018           China
# 20                  goPuff           $15    10/8/2020   United States
# 21           Yuanqi Senlin           $15     3/1/2020           China
# 22                  Ripple           $15   12/20/2019   United States
# 23                   Plaid        $13.40   12/11/2018   United States
# 24                 OpenSea        $13.30    7/20/2021   United States
# 25               Grammarly           $13   10/10/2019   United States
# 26          Devoted Health        $12.60   10/16/2018   United States
# 27                   Faire        $12.40   10/30/2019   United States
# 28                    Brex        $12.30    10/5/2018   United States
# 29               JUUL Labs           $12   12/20/2017   United States
# 30    Bitmain Technologies           $12     7/6/2018           China
# 31  Biosplice Therapeutics           $12     8/6/2018   United States
# 32                GoodLeap           $12   10/13/2021   United States
# 33                Airtable        $11.70   11/15/2018   United States
# 34       ZongMu Technology        $11.40     6/3/2021           China
# 35           Global Switch        $11.10   12/22/2016  United Kingdom
# 36                 Celonis           $11    6/26/2018         Germany
# 37                    Bolt           $11    10/8/2021   United States
# 38                 Alchemy        $10.20   10/28/2021   United States
# 39                 Weilong        $10.88     5/8/2021           China
# 40                  Swiggy        $10.70    6/21/2018           India
# 41                Lalamove           $10    2/21/2019       Hong Kong
# 42                   Figma           $10    4/30/2020   United States
# 43                   Gusto           $10   12/18/2015   United States
# 44                  reddit           $10    7/31/2017   United States
# 45                Talkdesk           $10    10/3/2018   United States
# 46             Notion Labs           $10     4/1/2020   United States
# 47                 Thrasio           $10    7/15/2020   United States
# 48  Digital Currency Group           $10    11/1/2021   United States
# 49              OutSystems         $9.50     6/5/2018   United States
#
#               City                                Industry  \
# 0          Beijing                 Artificial intelligence
# 1        Hawthorne                                   Other
# 2    San Francisco                                 Fintech
# 3        Stockholm                                 Fintech
# 4             Cary                                   Other
# 5      Surry Hills            Internet software & services
# 6           London                                 Fintech
# 7    San Francisco     Supply chain, logistics, & delivery
# 8    San Francisco             Data management & analytics
# 9           London                                 Fintech
# 10         Fintech  Sequoia Capital, Thoma Bravo, Softbank
# 11    Jacksonville         E-commerce & direct-to-consumer
# 12   San Francisco                                 Fintech
# 13       Bengaluru                                  Edtech
# 14        Shanghai         E-commerce & direct-to-consumer
# 15         Jakarta     Supply chain, logistics, & delivery
# 16   San Francisco            Internet software & services
# 17         Beijing                                  Edtech
# 18        Shenzhen                                Hardware
# 19        Shenzhen         E-commerce & direct-to-consumer
# 20    Philadelphia         E-commerce & direct-to-consumer
# 21         Beijing                       Consumer & retail
# 22   San Francisco                                 Fintech
# 23   San Francisco                                 Fintech
# 24        New York         E-commerce & direct-to-consumer
# 25   San Francisco            Internet software & services
# 26         Waltham                                  Health
# 27   San Francisco                 Artificial intelligence
# 28   San Francisco                                 Fintech
# 29   San Francisco                       Consumer & retail
# 30         Beijing                                Hardware
# 31       San Diego                                  Health
# 32       Roseville            Internet software & services
# 33   San Francisco            Internet software & services
# 34        Shanghai                   Auto & transportation
# 35          London                                Hardware
# 36          Munich             Data management & analytics
# 37   San Francisco                                 Fintech
# 38   San Francisco                                 Fintech
# 39           Luohe                       Consumer & retail
# 40       Bengaluru     Supply chain, logistics, & delivery
# 41  Cheung Sha Wan     Supply chain, logistics, & delivery
# 42   San Francisco            Internet software & services
# 43   San Francisco                                 Fintech
# 44   San Francisco            Internet software & services
# 45   San Francisco            Internet software & services
# 46   San Francisco            Internet software & services
# 47         Walpole                                   Other
# 48        New York                                Finttech
# 49          Boston            Internet software & services
#
#                                     Select Inverstors Founded Year  \
# 0   Sequoia Capital China, SIG Asia Investments, S...         2012
# 1   Founders Fund, Draper Fisher Jurvetson, Rothen...         2002
# 2         Khosla Ventures, LowercaseCapital, capitalG         2010
# 3   Institutional Venture Partners, Sequoia Capita...         2005
# 4               Tencent Holdings, KKR, Smash Ventures         1991
# 5   Sequoia Capital China, Blackbird Ventures, Mat...         2012
# 6   Tiger Global Management, Insight Partners, DST...         2012
# 7   Khosla Ventures, Kleiner Perkins Caufield & By...         2012
# 8   Andreessen Horowitz, New Enterprise Associates...         2013
# 9          index Ventures, DST Global, Ribbit Capital         2015
# 10                                               None         2018
# 11  SoftBank Group, Andreessen Horowitz, Temasek H...         1995
# 12   Forerunner Ventures, Crosslink Capital, Homebrew         2013
# 13  Tencent Holdings, Lightspeed India Partners, S...         2008
# 14                     GGV Capital, ZhenFund, Tencent         2013
# 15  Hillhouse Capital Management, Boyu Capital, Se...         2015
# 16  Accel, AltaIR Capital, Technology Crossover Ve...         2011
# 17       Tencent Holdings, Warbug Pincus, IDG Capital         2012
# 18                    Accel Partners, Sequoia Capital         2006
# 19  Tiger Global Management, Sequoia Capital China...         2008
# 20              Accel, Softbank Group, Anthos Capital         2013
# 21  Sequoia Capital China, Longfor Capitalm, Gaoro...         2016
# 22  IDG Capital, Venture51, Lightspeed Venture Par...         2012
# 23  New Enterprise Associates, Spar Capital, Index...         2012
# 24  Andreessen Horowitz, Thirty Five Ventures, Sou...         2017
# 25  General Catalyst, Institutional Venture Partne...         2009
# 26      Andreessen Horowitz, F-Prime Capital, Venrock         2017
# 27  Khosla Ventures, Forerunner Ventures, Sequoia ...         2017
# 28  DST Global, Ribbit Capital, Greenoaks Capital ...         2017
# 29                            Tiger Global Management         2015
# 30  Coatue Management, Sequoia Capital China, IDG ...         2015
# 31           Vickers Venture Partners, IKEA GreenTech         2008
# 32  New Enterprise Associates, BDT Capital Partner...         2003
# 33       Caffeinated Capital, CRV, Founder Collective         2013
# 34     LTW Capital, Legend Capital, Qualcomm Ventures         2013
# 35  Aviation Industry Corporation of China, Essenc...         1998
# 36                                     Accel, 83North         2011
# 37  Activant Capital, Tribe Capital, General Atlantic         2014
# 38       DFJ Growth Fund, Coatue Management, Addition         2017
# 39  Tencent Holdings, Hillhouse Capital Management...         None
# 40  Accel India, SAIF Partners, Norwest Venture Pa...         2014
# 41  MindWorks Ventures, Shunwei Capital Partners, ...         2013
# 42  Index Ventures, Greylock Partners, Kleiner Per...         2012
# 43  General Catalyst Partners, Google Ventures, Kl...         2011
# 44   Y Combinator, Sequoia Capital, Coatue Management         2005
# 45           DJF, Salesforce Ventures, Storm Ventures         2011
# 46   Index Ventures, Draft Ventures, Felicis Ventures         2016
# 47  Upper90, RiverPark Ventures, Advent International         2018
# 48           Ribbit Capital, capitalG, Softbank Group         2018
# 49       KKR, ES Ventures, North Bridge Growth Equity         2001
#
#    Total Raised Financial Stage Investors Count Deal Terms Portfolio Exits
# 0        $7.44B             IPO              28          8               5
# 1       $6.874B            None              29         12            None
# 2       $2.901B           Asset              39         12               1
# 3       $3.472B        Acquired              56         13               1
# 4       $4.377B        Acquired              25          5               2
# 5      $571.26M            None              26          8            None
# 6        $1.83B            None              15          4            None
# 7       $2.686B            None              29         12            None
# 8       $3.497B            None              29          8            None
# 9       $1.716B            None              31          6            None
# 10      $1.829B             Acq              40          3               1
# 11       $4.19B            None              21         10            None
# 12      $2.599B     Divestiture              24          9               1
# 13      $5.183B            None              45         19            None
# 14      $917.5M            None               9          3            None
# 15      $4.653B            None               9          3            None
# 16        $475M            None              18          1            None
# 17      $4.044B        Acquired              18          7               1
# 18      $1.135B            None               7          3            None
# 19     $553.36M            None               8          3            None
# 20      $3.397B            None              16          4            None
# 21     $721.31M            None              13          3            None
# 22      $293.9M             Acq              34          5               1
# 23      $734.8M            None              24          5            None
# 24     $425.12M            None              26          2            None
# 25        $400M            None               8          3            None
# 26      $1.969B            None              16          4            None
# 27      $1.096B            None              14          6            None
# 28       $1.49B            None              28          7            None
# 29       $1.49B            None              28          7            None
# 30       $1.49B            None              28          7            None
# 31      $561.5M            None              10          1            None
# 32        $1.8B            None               8          1            None
# 33      $1.353B            None              41          6            None
# 34     $210.83M            None              19          2            None
# 35      $6.255B            None               6          2            None
# 36      $1.368B            None              13          4            None
# 37        $963M            None              37          3            None
# 38        $545M            None              27          3            None
# 39     $559.74M            None               7          1            None
# 40      $3.571B        Acquired              36         12               1
# 41      $2.475B            None              15          5            None
# 42      $333.5M            None              20          6            None
# 43     $691.12M            None              70          9            None
# 44      $1.326B        Acquired              33          5               1
# 45     $504.77M            None              19          6            None
# 46        $342M            None              17          3            None
# 47      $3.396B        Acquired              22          5               1
# 48      $3.396B        Acquired              22          5               1
# 49     $572.01M            None              13          3            None

# %%
df['Financial Stage'].unique()
# Out:
# array(['IPO', 'None', 'Asset', 'Acquired', 'Acq', 'Divestiture', 'Take',
#        'Management', 'Reverse', 'Corporate'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1037 entries, 0 to 1036
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            1037 non-null   object
#  1   Valuation ($B)     1037 non-null   object
#  2   Date Joined        1037 non-null   object
#  3   Country            1037 non-null   object
#  4   City               1037 non-null   object
#  5   Industry           1037 non-null   object
#  6   Select Inverstors  1037 non-null   object
#  7   Founded Year       1037 non-null   object
#  8   Total Raised       1037 non-null   object
#  9   Financial Stage    1037 non-null   object
#  10  Investors Count    1037 non-null   object
#  11  Deal Terms         1037 non-null   object
#  12  Portfolio Exits    1037 non-null   object
# dtypes: object(13)
# memory usage: 105.4+ KB

# %% [markdown]
# **Dictionary**
#
# Company: The name of the company.
#
# Valuation ($B): The valuation of the company in billions of dollars.
#
# Date Joined: The date when the company joined the unicorn club.
#
# Country: The country where the company is based.
#
# City: The city where the company is based.
#
# Industry: The industry in which the company operates.
#
# Select Investors: Key investors in the company.
#
# Founded Year: The year the company was founded.
#
# Total Raised: The total amount of funding the company has raised.
#
# Financial Stage: The current financial stage of the company (e.g., IPO, Acquired).
#
# Investors Count: The number of investors in the company.
#
# Deal Terms: The number of deal terms the company has had.
#
# Portfolio Exits: The number of portfolio exits the company has had.

# %% [markdown]
# Now, let's proceed to the **data cleaning** stage.
#
#
# 1. Clean the Valuation field with the $ sign and convert the value to numeric.
#
#
# ---
#
#
# 2. Clean the Total Raised field to remove the '$' sign and 'B' (for billion),Million and Thousands and convert the value to numeric.
#
# 3. Clean the Industry field to have consistent names.
#
# 4. Clean the Financial Stage field to have consistent names.
# 5. Missing values

# %%
df.isnull().sum()
# Out:
# Company              0
# Valuation ($B)       0
# Date Joined          0
# Country              0
# City                 0
# Industry             0
# Select Inverstors    0
# Founded Year         0
# Total Raised         0
# Financial Stage      0
# Investors Count      0
# Deal Terms           0
# Portfolio Exits      0
# dtype: int64

# %%
# Modify the clean_total_raised function to handle 'None' values and cases where the Total Raised field is already in dollars

def clean_total_raised(value):
    if pd.isnull(value) or value == 'None':
        return None
    if 'B' in value:
        return float(value.replace('$', '').replace('B', '')) * 1e9  # Convert to dollars
    elif 'M' in value:
        return float(value.replace('$', '').replace('M', '')) * 1e6  # Convert to dollars
    elif 'K' in value:
        return float(value.replace('$', '').replace('K', '')) * 1e3  # Convert to dollars
    else:
        return float(value.replace('$', ''))

df['Total Raised'] = df['Total Raised'].apply(clean_total_raised)

# Display the first few rows of the dataframe
df.head()
# Out:
#       Company Valuation ($B) Date Joined        Country           City  \
# 0   Bytedance          $140     4/7/2017          China        Beijing
# 1      SpaceX       $100.30    12/1/2012  United States      Hawthorne
# 2      Stripe           $95    1/23/2014  United States  San Francisco
# 3      Klarna        $45.60   12/12/2011         Sweden      Stockholm
# 4  Epic Games           $42   10/26/2018  United States           Cary
#
#                   Industry                                  Select Inverstors  \
# 0  Artificial intelligence  Sequoia Capital China, SIG Asia Investments, S...
# 1                    Other  Founders Fund, Draper Fisher Jurvetson, Rothen...
# 2                  Fintech        Khosla Ventures, LowercaseCapital, capitalG
# 3                  Fintech  Institutional Venture Partners, Sequoia Capita...
# 4                    Other              Tencent Holdings, KKR, Smash Ventures
#
#   Founded Year  Total Raised Financial Stage Investors Count Deal Terms  \
# 0         2012  7.440000e+09             IPO              28          8
# 1         2002  6.874000e+09            None              29         12
# 2         2010  2.901000e+09           Asset              39         12
# 3         2005  3.472000e+09        Acquired              56         13
# 4         1991  4.377000e+09        Acquired              25          5
#
#   Portfolio Exits
# 0               5
# 1            None
# 2               1
# 3               1
# 4               2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1037 entries, 0 to 1036
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            1037 non-null   object
#  1   Valuation ($B)     1037 non-null   object
#  2   Date Joined        1037 non-null   object
#  3   Country            1037 non-null   object
#  4   City               1037 non-null   object
#  5   Industry           1037 non-null   object
#  6   Select Inverstors  1037 non-null   object
#  7   Founded Year       1037 non-null   object
#  8   Total Raised       1013 non-null   float64
#  9   Financial Stage    1037 non-null   object
#  10  Investors Count    1037 non-null   object
#  11  Deal Terms         1037 non-null   object
#  12  Portfolio Exits    1037 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 105.4+ KB

# %%
df.head(100)

# %%
df['Industry'].unique()
# Out:
# array(['Artificial intelligence', 'Other', 'Fintech',
#        'Internet software & services',
#        'Supply chain, logistics, & delivery',
#        'Data management & analytics',
#        'Sequoia Capital, Thoma Bravo, Softbank',
#        'E-commerce & direct-to-consumer', 'Edtech', 'Hardware',
#        'Consumer & retail', 'Health', 'Auto & transportation', 'Finttech',
#        'Cybersecurity', 'Mobile & telecommunications', 'Travel',
#        'Kuang-Chi',
#        'Tiger Global Management, Tiger Brokers, DCM Ventures',
#        'Jungle Ventures, Accel, Venture Highway',
#        'Artificial Intelligence',
#        'Vision Plus Capital, GSR Ventures, ZhenFund',
#        'Hopu Investment Management, Boyu Capital, DC Thomson Ventures',
#        '500 Global, Rakuten Ventures, Golden Gate Ventures',
#        'Sequoia Capital China, ING, Alibaba Entrepreneurs Fund',
#        'Sequoia Capital China, Shunwei Capital Partners, Qualgro',
#        'Dragonfly Captial, Qiming Venture Partners, DST Global',
#        'SingTel Innov8, Alpha JWC Ventures, Golden Gate Ventures',
#        'Mundi Ventures, Doqling Capital Partners, Activant Capital',
#        'Vertex Ventures SE Asia, Global Founders Capital, Visa Ventures',
#        'Andreessen Horowitz, DST Global, IDG Capital',
#        "B Capital Group, Monk's Hill Ventures, Dynamic Parcel Distribution",
#        'Temasek, Guggenheim Investments, Qatar Investment Authority'],
#       dtype=object)

# %%
# Correct the typo in 'Finttech'
df['Industry'] = df['Industry'].replace('Finttech', 'Fintech')

# %%
# List of known industries
known_industries = ['Artificial intelligence', 'Fintech',
                    'Internet software & services',
                    'Supply chain, logistics, & delivery',
                    'Data management & analytics',
                    'E-commerce & direct-to-consumer', 'Edtech', 'Hardware',
                    'Consumer & retail', 'Health', 'Auto & transportation',
                    'Cybersecurity', 'Mobile & telecommunications', 'Travel']

# If the industry is not in the known industries list, categorize it as 'Other'
df['Industry'] = df['Industry'].apply(lambda x: x if x in known_industries else 'Other')



# Check the unique values of the Industry field
industry_values_cleaned = df['Industry'].unique()

industry_values_cleaned
# Out:
# array(['Artificial intelligence', 'Other', 'Fintech',
#        'Internet software & services',
#        'Supply chain, logistics, & delivery',
#        'Data management & analytics', 'E-commerce & direct-to-consumer',
#        'Edtech', 'Hardware', 'Consumer & retail', 'Health',
#        'Auto & transportation', 'Cybersecurity',
#        'Mobile & telecommunications', 'Travel'], dtype=object)

# %%
# Clean the Financial Stage fields as before
df['Financial Stage'] = df['Financial Stage'].replace('Acq', 'Acquired')

# %%
df['Valuation ($B)'] = df['Valuation ($B)'].str.replace('$', '')

# Convert the value to numeric
df['Valuation ($B)'] = pd.to_numeric(df['Valuation ($B)'], errors='coerce')
# Out:
# <ipython-input-15-7cf59079a576>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Valuation ($B)'] = df['Valuation ($B)'].str.replace('$', '')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1037 entries, 0 to 1036
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            1037 non-null   object
#  1   Valuation ($B)     1037 non-null   float64
#  2   Date Joined        1037 non-null   object
#  3   Country            1037 non-null   object
#  4   City               1037 non-null   object
#  5   Industry           1037 non-null   object
#  6   Select Inverstors  1037 non-null   object
#  7   Founded Year       1037 non-null   object
#  8   Total Raised       1013 non-null   float64
#  9   Financial Stage    1037 non-null   object
#  10  Investors Count    1037 non-null   object
#  11  Deal Terms         1037 non-null   object
#  12  Portfolio Exits    1037 non-null   object
# dtypes: float64(2), object(11)
# memory usage: 105.4+ KB

# %%
# Descriptive Analysis

# Measures of central tendency and dispersion for numeric variables
numeric_descriptive = df[['Valuation ($B)', 'Total Raised']].describe()

# Frequency counts for categorical variables
categorical_descriptive = df[['Industry', 'Country', 'Financial Stage']].apply(lambda x: x.value_counts()).T.stack()

numeric_descriptive, categorical_descriptive
# Out:
# (       Valuation ($B)  Total Raised
#  count     1037.000000  1.013000e+03
#  mean         3.292083  5.757672e+08
#  std          7.309781  7.360876e+08
#  min          1.000000  1.000000e+04
#  25%          1.080000  2.273400e+08
#  50%          1.600000  3.777000e+08
#  75%          3.100000  6.337800e+08
#  max        140.000000  7.440000e+09,
#  Industry         Artificial intelligence         71.0
#                   Auto & transportation           29.0
#                   Consumer & retail               25.0
#                   Cybersecurity                   49.0
#                   Data management & analytics     41.0
#                                                  ...
#  Financial Stage  IPO                              7.0
#                   Management                       1.0
#                   None                           988.0
#                   Reverse                          1.0
#                   Take                             1.0
#  Length: 70, dtype: float64)

# %%
# Out:
# <ipython-input-13-7cf59079a576>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Valuation ($B)'] = df['Valuation ($B)'].str.replace('$', '')

# %%
df

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def add_data_labels(ax, orientation):
    if orientation == 'vertical':
        for p in ax.patches:
            ax.annotate(format(p.get_height(), '.0f'),
                        (p.get_x() + p.get_width() / 2., p.get_height()),
                        ha = 'center',
                        va = 'center',
                        xytext = (0, 10),
                        textcoords = 'offset points')
    elif orientation == 'horizontal':
        for p in ax.patches:
            ax.annotate(format(p.get_width(), '.0f'),
                        (p.get_x() + p.get_width(), p.get_y() + p.get_height()/2),
                        ha = 'center',
                        va = 'center',
                        xytext = (10, 0),
                        textcoords = 'offset points')

# Industry Analysis
plt.figure(figsize=(10,6))
ax1 = sns.countplot(y="Industry", data=df, order = df['Industry'].value_counts().index)
add_data_labels(ax1, 'horizontal')
plt.title("Distribution of Unicorn Companies by Industry")
plt.xlabel("Count")
plt.ylabel("Industry")
plt.savefig('industry_analysis.png', dpi=300, bbox_inches='tight')

# Country Analysis
plt.figure(figsize=(10,6))
ax2 = sns.countplot(y="Country", data=df, order = df['Country'].value_counts().index)
add_data_labels(ax2, 'horizontal')
plt.title("Distribution of Unicorn Companies by Country")
plt.xlabel("Count")
plt.ylabel("Country")
plt.savefig('country_analysis.png', dpi=300, bbox_inches='tight')

# Valuation Analysis
plt.figure(figsize=(10,6))
ax3 = sns.histplot(df['Valuation ($B)'], bins=20, kde=False)
add_data_labels(ax3, 'vertical')
plt.title("Distribution of Valuations of Unicorn Companies")
plt.xlabel("Valuation ($B)")
plt.ylabel("Count")
plt.savefig('valuation_analysis.png', dpi=300, bbox_inches='tight')

# Total Raised Analysis
plt.figure(figsize=(10,6))
ax4 = sns.histplot(df['Total Raised'], bins=20, kde=False)
add_data_labels(ax4, 'vertical')
plt.title("Distribution of Total Raised by Unicorn Companies")
plt.xlabel("Total Raised ($)")
plt.ylabel("Count")
plt.savefig('total_raised_analysis.png', dpi=300, bbox_inches='tight')

# Financial Stage Analysis
plt.figure(figsize=(10,6))
ax5 = sns.countplot(y="Financial Stage", data=df, order = df['Financial Stage'].value_counts().index)
add_data_labels(ax5, 'horizontal')
plt.title("Distribution of Unicorn Companies by Financial Stage")
plt.xlabel("Count")
plt.ylabel("Financial Stage")
plt.savefig('financial_stage_analysis.png', dpi=300, bbox_inches='tight')

# %%
df

# %%
# Correlation Analysis

# Calculate the correlation matrix
correlation_matrix = df[['Valuation ($B)', 'Total Raised']].corr()

# Display the correlation matrix
correlation_matrix
# Out:
#                 Valuation ($B)  Total Raised
# Valuation ($B)        1.000000      0.616879
# Total Raised          0.616879      1.000000

# %% [markdown]
# The **correlation matrix** shows the correlation between the numeric variables Valuation ($B) and Total Raised. The correlation coefficient is approximately 0.62, indicating a moderate to strong positive correlation. This suggests that companies that have raised more funds tend to have higher valuations, which is a reasonable expectation. However, correlation does not imply causation, and other factors could also influence these variables.

# %%
pip install reportlab
# Out:
# Requirement already satisfied: reportlab in /usr/local/lib/python3.10/dist-packages (4.0.4)
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from reportlab) (9.4.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
from reportlab.lib.utils import ImageReader
from reportlab.platypus import SimpleDocTemplate, PageBreak, Paragraph, Image, Table
from reportlab.lib.styles import getSampleStyleSheet
from reportlab.lib.units import inch

# %%
from reportlab.lib.pagesizes import letter
from reportlab.lib.utils import ImageReader
from reportlab.platypus import SimpleDocTemplate, PageBreak, Paragraph, Image
from reportlab.lib.styles import getSampleStyleSheet
from reportlab.lib.units import inch

# Create a SimpleDocTemplate
doc = SimpleDocTemplate("unicorn_analysis_report-3rdaug.pdf", pagesize=letter)

# Create a list to hold the report elements
elements = []

# Add a title, company name, and logo to the report
elements.append(Paragraph("Company : Decoding Data Science", getSampleStyleSheet()['Heading1']))
logo = "logo-highres.jpg"
im = Image(logo, 2*inch, 2*inch)
elements.append(im)

# Add the descriptive statistics to the report
elements.append(Paragraph("Descriptive Statistics:", getSampleStyleSheet()['Heading2']))
elements.append(Paragraph(str(numeric_descriptive)))
elements.append(Paragraph(str(categorical_descriptive)))

# Add the correlation matrix to the report
elements.append(PageBreak())
elements.append(Paragraph("Correlation Matrix:", getSampleStyleSheet()['Heading2']))
elements.append(Paragraph(str(correlation_matrix)))

# Add the data visualizations to the report
elements.append(PageBreak())
elements.append(Paragraph("Data Visualizations:", getSampleStyleSheet()['Heading2']))
im = Image('industry_analysis.png', 5*inch, 5*inch)
elements.append(im)
im = Image('country_analysis.png', 5*inch, 5*inch)
elements.append(im)
im = Image('valuation_analysis.png', 5*inch, 5*inch)
elements.append(im)
im = Image('total_raised_analysis.png', 5*inch, 5*inch)
elements.append(im)
im = Image('financial_stage_analysis.png', 5*inch, 5*inch)
elements.append(im)


# Build the PDF
doc.build(elements)

# %%
from reportlab.lib.pagesizes import letter
from reportlab.lib.utils import ImageReader
from reportlab.platypus import SimpleDocTemplate, PageBreak, Paragraph, Image, Table, TableStyle, Spacer
from reportlab.lib.styles import getSampleStyleSheet
from reportlab.lib.units import inch, cm
from reportlab.lib import colors
from reportlab.lib.enums import TA_CENTER

# Create a SimpleDocTemplate
doc = SimpleDocTemplate("unicorn_analysis_report-3rdaug.pdf", pagesize=letter)

# Create a list to hold the report elements
elements = []

# Add a title, company name, and logo to the report
styles = getSampleStyleSheet()
styles['Heading1'].alignment = TA_CENTER
elements.append(Spacer(1, 2*cm))
elements.append(Paragraph("Unicorn Startup Analysis", styles['Heading1']))
elements.append(Spacer(1, 1*cm))
elements.append(Paragraph("By Mohammad Arshad", styles['Heading1']))
elements.append(Spacer(1, 2*cm))
logo = "logo-highres.jpg"
im = Image(logo, 2*inch, 2*inch, hAlign='CENTER')
elements.append(im)
elements.append(PageBreak())

# Add the descriptive statistics to the report
elements.append(Paragraph("Descriptive Statistics:", styles['Heading2']))
# Convert the descriptive statistics DataFrame to a list of lists and add to a Table object
table1 = Table(numeric_descriptive.reset_index().values.tolist(), hAlign='LEFT')
table1.setStyle(TableStyle([('BOX', (0, 0), (-1, -1), 1, colors.black),
                            ('INNERGRID', (0, 0), (-1, -1), 0.25, colors.black)]))
elements.append(table1)

# Add the correlation matrix to the report
elements.append(PageBreak())
elements.append(Paragraph("Correlation Matrix:", styles['Heading2']))
# Convert the correlation matrix DataFrame to a list of lists and add to a Table object
table2 = Table(correlation_matrix.reset_index().values.tolist(), hAlign='LEFT')
table2.setStyle(TableStyle([('BOX', (0, 0), (-1, -1), 1, colors.black),
                            ('INNERGRID', (0, 0), (-1, -1), 0.25, colors.black)]))
elements.append(table2)

# Add the data visualizations to the report
elements.append(PageBreak())
elements.append(Paragraph("Data Visualizations:", styles['Heading2']))
im = Image('industry_analysis.png', 5*inch, 5*inch)
elements.append(im)
im = Image('country_analysis.png', 5*inch, 5*inch)
elements.append(im)
im = Image('valuation_analysis.png', 5*inch, 5*inch)
elements.append(im)
im = Image('total_raised_analysis.png', 5*inch, 5*inch)
elements.append(im)
im = Image('financial_stage_analysis.png', 5*inch, 5*inch)
elements.append(im)

# Build the PDF
doc.build(elements)
