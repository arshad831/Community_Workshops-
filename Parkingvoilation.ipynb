# %% [markdown]
# <a href="https://colab.research.google.com/github/arshad831/Community_Workshops-/blob/main/Parkingvoilation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
# !wget https://data.rapids.ai/datasets/nyc_parking/nyc_parking_violations_2022.parquet -O /tmp/nyc_parking_violations_2022.parquet
# Out:
# --2024-05-27 17:39:21--  https://data.rapids.ai/datasets/nyc_parking/nyc_parking_violations_2022.parquet
# Resolving data.rapids.ai (data.rapids.ai)... 13.224.163.13, 13.224.163.100, 13.224.163.5, ...
# Connecting to data.rapids.ai (data.rapids.ai)|13.224.163.13|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 474211285 (452M) [binary/octet-stream]
# Saving to: ‘/tmp/nyc_parking_violations_2022.parquet’
#
# /tmp/nyc_parking_vi 100%[===================>] 452.24M  20.0MB/s    in 25s
#
# 2024-05-27 17:39:47 (18.4 MB/s) - ‘/tmp/nyc_parking_violations_2022.parquet’ saved [474211285/474211285]

# %%
# read 5 columns data:
df = pd.read_parquet(
    "/tmp/nyc_parking_violations_2022.parquet",
    columns=["Registration State", "Violation Description", "Vehicle Body Type", "Issue Date", "Summons Number"]
)

# view a random sample of 10 rows:
df.sample(10)
# Out:
#          Registration State           Violation Description Vehicle Body Type  \
# 1709174                  NY  71A-Insp Sticker Expired (NYS)              4DSD
# 255012                   NY  PHTO SCHOOL ZN SPEED VIOLATION              4DSD
# 12240875                 NY  38-Failure to Dsplay Meter Rec              SUBN
# 5433245                  NY  PHTO SCHOOL ZN SPEED VIOLATION              4DSD
# 13295111                 NY  PHTO SCHOOL ZN SPEED VIOLATION              4DSD
# 13343622                 NY  PHTO SCHOOL ZN SPEED VIOLATION              SUBN
# 4788952                  NJ   16-No Std (Com Veh) Com Plate              PICK
# 12215736                 NY  74A-Improperly Displayed Plate              4DSD
# 14912121                 NJ  38-Failure to Dsplay Meter Rec               VAN
# 3192256                  NY    21-No Parking (street clean)              SUBN
#
#           Issue Date  Summons Number
# 1709174   08/04/2021      8965520629
# 255012    07/16/2021      4740739641
# 12240875  04/04/2022      8992068967
# 5433245   11/04/2021      4755285914
# 13295111  05/16/2022      4779131455
# 13343622  05/19/2022      4779599258
# 4788952   10/14/2021      8700468861
# 12215736  04/20/2022      8972116919
# 14912121  06/25/2022      8585271309
# 3192256   08/30/2021      8982082943
